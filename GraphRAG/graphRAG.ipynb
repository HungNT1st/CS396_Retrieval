# %%
# %cd GraphRAG
# !python -m graphrag init --root ./graphrag_index
# Out:
# Initializing project at /Users/htn/CS396_Retrieval/graphrag_index
# ⠋ GraphRAG Indexer ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /Users/htn/opt/anaconda3/envs/retrieval/lib/python3.12/site-packages/graphra │
# │ g/cli/main.py:103 in _initialize_cli                                         │
# │                                                                              │
# │   100 │   """Generate a default configuration file."""                       │
# │   101 │   from graphrag.cli.initialize import initialize_project_at          │
# │   102 │                                                                      │
# │ ❱ 103 │   initialize_project_at(path=root, force=force)                      │
# │   104                                                                        │
# │   105                                                                        │
# │   106 @app.command("index")                                                  │
# ...

# %%
# %cd GraphRAG
# !python -m graphrag --help
# Out:
#
#  Usage: graphrag [OPTIONS] COMMAND [ARGS]...
#
#  GraphRAG: A graph-based retrieval-augmented generation (RAG) system.
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --install-completion          Install completion for the current shell.      │
# │ --show-completion             Show completion for the current shell, to copy │
# │                               it or customize the installation.              │
# │ --help                        Show this message and exit.                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ───────────────────────────────────────────────────────────────────╮
# │ init          Generate a default configuration file.                         │
# │ index         Build a knowledge graph index.                                 │
# │ update        Update an existing knowledge graph index.                      │
# ...

# %%
# !python -m graphrag index --root ./graphrag_index
# Out:
# Logging enabled at r
# /Users/htn/CS396_Retrieval/graphrag_index/logs/indexing-engine.log
# 🚀 LLM Config Params Validated
# 🚀 Embedding LLM Config Params Validated
# Running standard indexing.
# ⠦ GraphRAG Indexer
# ⠧ GraphRAG Indexer e.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠧ GraphRAG Indexer e.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# 🚀 create_base_text_unitses loaded (0 filtered) ━ 100% … 0…
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
#                                                   id  ... n_tokens 0:00:00
# 0  a014009e85631809408f1a6583a4e722420588d28892fd...  ...     1200
# 1  639c266fc3d2b5f2abd72fa7270c43d8a22b68bed216c6...  ...     1200
# 2  aefa516f7472a44e48398761e4dfebdf74d13ee6a25b97...  ...     1200
# 3  a614610a58c9ec705a54e6ea8259b7d3edc18ffc7c8770...  ...     1200
# 4  d1ca1a40161f34a21493b5f3d66da4284be71c11b5b93f...  ...     1200
# ...

# %%
root = './graphrag_index/output'

# %%
import pandas as pd

communities = pd.read_parquet(f"{root}/communities.parquet")
print(communities.columns)
print(communities.head())
# Out:
# Index(['id', 'human_readable_id', 'community', 'level', 'parent', 'children',
#        'title', 'entity_ids', 'relationship_ids', 'text_unit_ids', 'period',
#        'size'],
#       dtype='object')
#                                      id  human_readable_id  community  level  \
# 0  34745c5d-1914-4053-87a2-ecb4ac402c02                  0          0      0
# 1  29b90a9a-ffce-4204-bc52-8b610233f4c9                  1          1      0
# 2  b3c5755d-8f76-4674-a5d0-1470211cb8a8                  2          2      0
# 3  3f76671c-5a80-43f5-872f-aff01032078f                  3          3      0
# 4  26200f1a-47be-438a-9c08-b79b964aa026                  4          4      0
#
#    parent children        title  \
# 0      -1       []  Community 0
# 1      -1  [9, 10]  Community 1
# 2      -1       []  Community 2
# 3      -1       []  Community 3
# 4      -1       []  Community 4
#
#                                           entity_ids  \
# ...

# %%
# Q&A using the terminal
# Global query
# !graphrag query --root ./graphrag_index --method global --query "What are the top themes in this story?"
# Out:
# SUCCESS: Global Search Response:
# # Top Themes in the Renaissance Story
#
# The Renaissance period, marked by a resurgence of art, culture, and intellectual pursuit, is characterized by several key themes that have significantly shaped its narrative. The following sections outline the most prominent themes derived from the analysis of the dataset.
#
# ## The Genius of Leonardo da Vinci
#
# Leonardo da Vinci stands out as a central figure of the Renaissance, whose multifaceted contributions to art, science, and engineering have left an indelible mark across various disciplines. His masterpieces, including the 'Mona Lisa' and 'The Last Supper,' exemplify innovative techniques and a profound understanding of natural laws, showcasing the blend of artistic and scientific inquiry that defines the era [Data: Reports (0, 1, 9, 8, 3)].
#
# ## The Role of Patronage
#
# ...

# %%
# !ls
# Out:
# graphRAG.ipynb      graphrag-api        graphrag-visualizer graphrag_index
# /Users/htn/CS396_Retrieval/GraphRAG/graphrag_index

# %%
# Local query
# !graphrag query --root ./graphrag_index --method local --query "Who is Leonardo Da Vinci and what are his main relationships?"
# Out:
# INFO: Vector Store Args: {
#     "default_vector_store": {
#         "type": "lancedb",
#         "db_uri": "/Users/htn/CS396_Retrieval/GraphRAG/graphrag_index/output/lancedb",
#         "url": null,
#         "audience": null,
#         "container_name": "==== REDACTED ====",
#         "database_name": null,
#         "overwrite": true
#     }
# }
#
# SUCCESS: Local Search Response:
# ## Overview of Leonardo Da Vinci
#
# Leonardo da Vinci was a prominent figure of the Florentine Renaissance, celebrated as a polymath whose contributions spanned art, science, and engineering. He is best known for his masterpieces, including the iconic "Mona Lisa" and "The Last Supper," which exemplify his innovative techniques and deep understanding of natural laws. His work has left a lasting impact on multiple disciplines, making him a central figure in the history of the Renaissance [Data: Reports (0, 1); Entities (0)].
#
# ## Key Relationships
#
# ### Family
#
# ...
